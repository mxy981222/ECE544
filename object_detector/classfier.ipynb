# %%
import torch
from torch.utils.data import Dataset
import numpy as np
import json
import random
from PIL import Image
from matplotlib import cm
from IPython.display import display
import os

# %%
torch.manual_seed(10)
np.random.seed(10)
random.seed(10)
print(torch.cuda.is_available())
# Out:
# False

# %%
data_dir = "../Project1/data"
image_dir = "../Project1/data/images"

# %%
class MyData(Dataset):
    def __init__(self):
        file = '../Project1/raw/data.json'
        f = open(file)
        self.data = json.load(f)
        f.close()
        self.labels = {} # filename: label
        self.box_w = []
        self.box_h = []
        self.images = {}
        self.bounding_boxes = {}
        self.x_train = []
        self.y_train = []
        self.gts = {}
        for key,val in self.data.items():
            try:
                imgPIL = Image.open('../Project1/raw/'+val['filename'])
                origwidth = imgPIL.size[0]
                origheight = imgPIL.size[1]
                imgPIL = imgPIL.resize((1280,1280),Image.LANCZOS)
                image = torch.Tensor(np.asarray(imgPIL)/255)
                self.images[val['filename']] = image
                gt = torch.zeros((image.shape[0:2]))
                box_data = [] # x_center, y_center, width, height (from 0 - 1)
                for k2,v2 in val['regions'].items():
                    rectdata = v2['shape_attributes']
                    x1 = int(np.floor(1280*float(rectdata['x'])/origwidth))
                    y1 = int(np.floor(1280*float(rectdata['y'])/origheight))
                    x2 = int(np.ceil(1280*float(rectdata['x']+rectdata['width'])/origwidth))
                    y2 = int(np.ceil(1280*float(rectdata['y']+rectdata['height'])/origheight))
                    gt[y1:y2,x1:x2] = 1
                    box_data.append([x1,y1,x2,y2])
                    self.box_w.append(x2-x1)
                    self.box_h.append(y2-y1)
                self.gts[val['filename']] = gt
                self.bounding_boxes[val['filename']] = box_data
                print('File: {}; number: {}'.format(val['filename'],len(val['regions'])))
            except IOError:
                print('File not found: {}'.format(val['filename']))
    def gen_train_data(self):
        i = 0
        for filename in self.images:
            image = self.images[filename]
            box_data = self.bounding_boxes[filename]
            gt = self.gts[filename]
            for x1,y1,x2,y2 in box_data:
                cropped = image[y1:min(y2,1280),x1:min(x2,1280),:]
                cropped_img = Image.fromarray(np.uint8((cropped.numpy())*255))
                cropped_img_path = os.path.join(image_dir,filename.split('.')[0]+"_"+str(i)+".jpg")
                i += 1
                # cropped_img.save(cropped_img_path)
                self.x_train.append(cropped_img)
                self.y_train.append(1)
                self.labels[cropped_img_path] = 1
            max_w,min_w,max_h,min_h = max(self.box_w),min(self.box_w),max(self.box_h),min(self.box_h)
            step = 10
            for k in range(200):
                x = random.randint(0,1280-max_w)
                y = random.randint(0,1280-max_h)
                # randomly pick some windows that do not contain nodes
                x1,x2,y1,y2 = x,x+max_w,y,y+max_h
                if np.sum(np.array(gt[y1:y2,x1:x2])) == 0:
                    cropped = image[y1:y2,x1:x2,:]
                    cropped_img = Image.fromarray(np.uint8((cropped.numpy())*255))
                    cropped_img_path = os.path.join(image_dir,filename.split('.')[0]+"_"+str(i)+".jpg")
                    i += 1
                    # cropped_img.save(cropped_img_path) no need to save
                    self.x_train.append(cropped_img)
                    self.y_train.append(0)
                    self.labels[cropped_img_path] = 0
                else:
                    k -= 1

    def __len__(self):
        return len(self.imgs)
    def __getitem__(self,idx):
        d,g = self.imgs[idx], self.gts[idx].unsqueeze(0)
        return d, g, idx

# %%
data = MyData()
# Out:
# File: 005-9-01.jpg; number: 276
# File: 022-5-02.jpg; number: 10
# File: 22-14-01.jpg; number: 261
# File: W005-4-05.jpg; number: 133
# File: W005-08-03.jpg; number: 426
# File: W005-08-04.jpg; number: 271
# File: W005-08-06.jpg; number: 199
# File: W005-14-02.jpg; number: 18
# File not found: W022-02-07.jpg
# File: W022-04-04.jpg; number: 237
# File: W022-07-03.jpg; number: 280
# File not found: W022-16-05.jpg
# File not found: W022-19-06.jpg
# File not found: W035-11-05.jpg
# File not found: W035-18-03.jpg
# File not found: W035-19-06.jpg
# File not found: W035-19-07.jpg
# File not found: W035-20-02.jpg

# %%
data.gen_train_data()

# %%
len(np.where(np.array(data.y_train)>0)[0])
# Out:
# 2111

# %% [markdown]
# # Start Training

# %%
from torchvision import transforms
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torchvision.models as models
from torch.utils.data import DataLoader
from torch.utils.data import random_split
import time
import copy

# %%
seed = 0
transform = transforms.Compose([
        transforms.Resize((64, 64)),
        transforms.ToTensor(),
        transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# %%
from torch.nn.modules.pooling import MaxPool2d
class myNet(nn.Module):
    def __init__(self):
        super(myNet, self).__init__()
        self.layer = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=4, stride=1, padding=0),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=(2,2),stride=2),
            nn.Conv2d(32, 64, kernel_size=2, stride=1, padding=0),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=(2,2),stride=2),
            nn.Conv2d(64, 128, kernel_size=2, stride=2, padding=0),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=(2,2),stride=2),
            nn.Dropout(0.25),
            nn.Flatten(),
            nn.Linear(in_features=1152,out_features=512),
            nn.ReLU(),
            nn.Linear(in_features=512,out_features=128),
            nn.ReLU(),
            nn.Linear(in_features=128,out_features=1),
            nn.Sigmoid(),
            )
        
    def forward(self, x):
        return self.layer(x)

# %%
class TrainDataset(Dataset):
    def __init__(self):
        self.x = []
        self.y = []

    def get_data(self,x_data,y_data):
        for im in x_data:
            self.x.append(transform(im))
        for l in y_data:
            self.y.append(torch.tensor(l, dtype=torch.float32))
    
    def __getitem__(self, i):
        return self.x[i], self.y[i]

    def __len__(self):
        return len(self.y)

# %%
net = myNet()
criterion = nn.BCELoss()
optimizer_ft = optim.Adam(net.parameters(), lr=0.002)
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)
device = "cpu"

# %%
train_data = TrainDataset()
train_data.get_data(data.x_train,data.y_train)

# %%
batch_size = 64
numTrain = int(len(train_data)*0.6)
numVal = int(len(train_data)*0.2)
numTest = len(train_data)-numTrain-numVal

# %%
train, val, test = random_split(train_data, [numTrain, numVal, numTest], generator=torch.Generator().manual_seed(seed))
trainloader = DataLoader(train, batch_size=batch_size,shuffle=True)
valloader = DataLoader(val, batch_size=batch_size,shuffle=False)
testloader = DataLoader(test, batch_size=batch_size,shuffle=False)
torch.save(trainloader, os.path.join(data_dir,"trainloader.pt"))
torch.save(valloader, os.path.join(data_dir,"valloader.pt"))
torch.save(testloader, os.path.join(data_dir,"testloader.pt"))

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()
    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)
        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            running_loss = 0.0
            running_corrects = 0
            correct = 0
            if phase == 'train':
                model.train()  # Set model to training mode
                for inputs, labels in trainloader:
                    inputs = inputs.to(device)
                    labels = labels.to(device)
                    # zero the parameter gradients
                    optimizer.zero_grad()
                    # forward
                    # track history if only in train
                    with torch.set_grad_enabled(phase == 'train'):
                        outputs = model(inputs).view(-1)
                        loss = criterion(outputs, labels)
                        # backward + optimize
                        optimizer.zero_grad()
                        loss.backward()
                        optimizer.step()
                        correct +=  (outputs.detach().numpy().round() == labels.detach().numpy()).sum().item()
                    # statistics
                    running_loss += loss.item() * inputs.size(0)
                print('train Accuracy:{:.4f}'.format(correct/len(trainloader.dataset)))
                scheduler.step()
                epoch_loss = running_loss / len(train_data)
            else:
                with torch.no_grad():
                    model.eval()   # Set model to evaluate mode
                    for inputs, labels in valloader:
                        inputs = inputs.to(device)
                        labels = labels.to(device)
                        # zero the parameter gradients
                        optimizer.zero_grad()
                        # forward
                        # track history if only in train
                        with torch.set_grad_enabled(phase == 'train'):
                            outputs = model(inputs).view(-1)
                            loss = criterion(outputs, labels)
                            correct +=  (outputs.detach().numpy().round() == labels.detach().numpy()).sum().item()
                        # statistics
                        running_loss += loss.item() * inputs.size(0)
                epoch_loss = running_loss / len(train_data)
                print('val Accuracy:{:.4f}'.format(correct/len(valloader.dataset)))
            # Iterate over data.

            print('{} Loss: {:.4f}'.format(
                phase, epoch_loss))
            # deep copy the model
        print()
    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    # load best model weights
    # model.load_state_dict(best_model_wts)
    return model

# %%
model = train_model(net, criterion, optimizer_ft, exp_lr_scheduler, num_epochs=10)
# Out:
# Epoch 0/9
# ----------
# train Accuracy:0.7567
# train Loss: 0.3408
# val Accuracy:0.8864
# val Loss: 0.0490
#
# Epoch 1/9
# ----------
# train Accuracy:0.9669
# train Loss: 0.0740
# val Accuracy:0.9778
# val Loss: 0.0163
#
# Epoch 2/9
# ----------
# train Accuracy:0.9765
# train Loss: 0.0438
# val Accuracy:0.9804
# val Loss: 0.0140
#
# Epoch 3/9
# ----------
# train Accuracy:0.9852
# train Loss: 0.0330
# val Accuracy:0.9791
# val Loss: 0.0126
#
# Epoch 4/9
# ----------
# train Accuracy:0.9856
# train Loss: 0.0269
# val Accuracy:0.9830
# val Loss: 0.0103
#
# Epoch 5/9
# ----------
# train Accuracy:0.9865
# train Loss: 0.0261
# val Accuracy:0.9830
# val Loss: 0.0100
#
# Epoch 6/9
# ----------
# train Accuracy:0.9869
# train Loss: 0.0255
# val Accuracy:0.9843
# val Loss: 0.0097
#
# Epoch 7/9
# ----------
# train Accuracy:0.9874
# train Loss: 0.0246
# val Accuracy:0.9843
# val Loss: 0.0095
#
# Epoch 8/9
# ----------
# train Accuracy:0.9878
# train Loss: 0.0247
# val Accuracy:0.9830
# val Loss: 0.0094
#
# Epoch 9/9
# ----------
# train Accuracy:0.9900
# train Loss: 0.0228
# val Accuracy:0.9843
# val Loss: 0.0092
#
# Training complete in 1m 58s

# %%
torch.save(model,os.path.join("./model.pt"))

# %%
model.eval()
correct = 0
with torch.no_grad():
    for inputs, labels in testloader:
        inputs = inputs.to(device)
        labels = labels.to(device)
        outputs = model(inputs.to(device))
        # print(outputs.view(-1))
        for i in range(len(outputs.detach().numpy().round())):
            print("pred:{},label:{}, correct:{}".format(outputs.detach().numpy()[i][0],labels.detach().numpy()[i],outputs.detach().numpy().round()[i][0]==labels.detach().numpy()[i]))
            if outputs.detach().numpy().round()[i][0]==labels.detach().numpy()[i]:
                correct +=  1
    print('accuracy: {}'.format(correct/len(testloader.dataset)))
# Out:
# pred:0.9968127608299255,label:1.0, correct:True
# pred:0.003394708037376404,label:0.0, correct:True
# pred:0.00015211626305244863,label:0.0, correct:True
# pred:0.010890219360589981,label:0.0, correct:True
# pred:0.9958603978157043,label:1.0, correct:True
# pred:0.015626968815922737,label:0.0, correct:True
# pred:0.9957160353660583,label:1.0, correct:True
# pred:0.9596471786499023,label:1.0, correct:True
# pred:0.000875182799063623,label:0.0, correct:True
# pred:0.0005397836212068796,label:0.0, correct:True
# pred:0.9905224442481995,label:1.0, correct:True
# pred:0.004358378238976002,label:0.0, correct:True
# pred:0.0008140229620039463,label:0.0, correct:True
# pred:4.833287312067114e-05,label:0.0, correct:True
# pred:0.014332939870655537,label:0.0, correct:True
# pred:0.0029386673122644424,label:0.0, correct:True
# pred:0.9987315535545349,label:1.0, correct:True
# pred:5.721901106880978e-05,label:0.0, correct:True
# pred:5.245916690910235e-05,label:0.0, correct:True
# pred:0.996148943901062,label:1.0, correct:True
# pred:0.9558937549591064,label:1.0, correct:True
# pred:0.9982141256332397,label:1.0, correct:True
# pred:0.00015226109826471657,label:0.0, correct:True
# pred:0.0024560869205743074,label:0.0, correct:True
# pred:0.9793675541877747,label:1.0, correct:True
# pred:0.9995030164718628,label:1.0, correct:True
# pred:0.005720238666981459,label:0.0, correct:True
# pred:0.008940628729760647,label:0.0, correct:True
# pred:0.9932464361190796,label:1.0, correct:True
# pred:0.9725884199142456,label:1.0, correct:True
# pred:0.998364269733429,label:1.0, correct:True
# pred:0.003004560014232993,label:0.0, correct:True
# pred:0.9812850952148438,label:1.0, correct:True
# pred:0.9997542500495911,label:1.0, correct:True
# pred:0.0011998140253126621,label:0.0, correct:True
# pred:0.008533661253750324,label:0.0, correct:True
# pred:0.010377735830843449,label:0.0, correct:True
# pred:0.9588558673858643,label:1.0, correct:True
# pred:0.9916182160377502,label:1.0, correct:True
# pred:0.9946763515472412,label:1.0, correct:True
# pred:0.0007758082938380539,label:0.0, correct:True
# pred:3.04192381008761e-05,label:0.0, correct:True
# pred:0.007369134575128555,label:0.0, correct:True
# pred:0.00010171806206926703,label:0.0, correct:True
# pred:0.00013749918434768915,label:0.0, correct:True
# pred:0.9977503418922424,label:1.0, correct:True
# pred:0.9409518241882324,label:0.0, correct:False
# pred:0.9846625328063965,label:1.0, correct:True
# pred:0.01035330817103386,label:0.0, correct:True
# pred:0.0001838565949583426,label:0.0, correct:True
# pred:0.0009366665035486221,label:0.0, correct:True
# pred:0.9961259961128235,label:1.0, correct:True
# pred:0.9953809976577759,label:1.0, correct:True
# pred:0.9965384006500244,label:1.0, correct:True
# pred:0.00023247925855685025,label:0.0, correct:True
# pred:0.05044029280543327,label:0.0, correct:True
# pred:0.0014996641548350453,label:0.0, correct:True
# pred:0.9942197799682617,label:1.0, correct:True
# pred:0.9954506754875183,label:1.0, correct:True
# pred:0.9391013979911804,label:1.0, correct:True
# pred:5.545983003685251e-05,label:0.0, correct:True
# pred:0.034723829478025436,label:0.0, correct:True
# pred:0.004361885134130716,label:0.0, correct:True
# pred:0.00494118919596076,label:0.0, correct:True
# pred:4.3854688556166366e-05,label:0.0, correct:True
# pred:0.9816933274269104,label:1.0, correct:True
# pred:0.008458806201815605,label:0.0, correct:True
# pred:0.0038137275259941816,label:0.0, correct:True
# pred:4.8763060476630926e-05,label:0.0, correct:True
# pred:0.9905673861503601,label:1.0, correct:True
# pred:0.9971926808357239,label:1.0, correct:True
# pred:0.005269480869174004,label:0.0, correct:True
# pred:0.9010343551635742,label:0.0, correct:False
# pred:0.9998548030853271,label:1.0, correct:True
# pred:0.0002682807098608464,label:0.0, correct:True
# pred:0.00010992529860232025,label:0.0, correct:True
# pred:0.0030023211147636175,label:0.0, correct:True
# pred:0.9983661770820618,label:1.0, correct:True
# pred:0.0014305434888228774,label:0.0, correct:True
# pred:0.9989864230155945,label:1.0, correct:True
# pred:0.9941153526306152,label:1.0, correct:True
# pred:0.9992057681083679,label:1.0, correct:True
# pred:0.5300400257110596,label:0.0, correct:False
# pred:0.002371254377067089,label:0.0, correct:True
# pred:0.9998500347137451,label:1.0, correct:True
# pred:0.006109592504799366,label:0.0, correct:True
# pred:0.6784913539886475,label:0.0, correct:False
# pred:0.0029127751477062702,label:0.0, correct:True
# pred:0.01151241920888424,label:0.0, correct:True
# pred:0.7580698132514954,label:0.0, correct:False
# pred:0.0010770679218694568,label:0.0, correct:True
# pred:9.969683742383495e-05,label:0.0, correct:True
# pred:0.0005221840110607445,label:0.0, correct:True
# pred:0.004462912678718567,label:0.0, correct:True
# pred:0.9948961138725281,label:1.0, correct:True
# pred:0.9979881048202515,label:1.0, correct:True
# pred:0.006937872618436813,label:0.0, correct:True
# pred:0.9989640712738037,label:1.0, correct:True
# pred:0.9991756081581116,label:1.0, correct:True
# pred:0.0021814145147800446,label:0.0, correct:True
# pred:0.9962418079376221,label:1.0, correct:True
# pred:0.9950063228607178,label:1.0, correct:True
# pred:0.9998840093612671,label:1.0, correct:True
# pred:0.9938369393348694,label:1.0, correct:True
# pred:0.9994682669639587,label:1.0, correct:True
# pred:0.9966455101966858,label:1.0, correct:True
# pred:0.0564366839826107,label:0.0, correct:True
# pred:0.967756450176239,label:1.0, correct:True
# pred:0.014417466707527637,label:0.0, correct:True
# pred:0.9962963461875916,label:1.0, correct:True
# pred:0.0015274705365300179,label:0.0, correct:True
# pred:0.07243603467941284,label:0.0, correct:True
# pred:0.9952148199081421,label:1.0, correct:True
# pred:0.004871706012636423,label:0.0, correct:True
# pred:0.006790797226130962,label:0.0, correct:True
# pred:0.004540800116956234,label:0.0, correct:True
# pred:0.9909186363220215,label:1.0, correct:True
# pred:0.9977430105209351,label:1.0, correct:True
# pred:0.0033002083655446768,label:0.0, correct:True
# pred:0.00666090939193964,label:0.0, correct:True
# pred:0.9960277080535889,label:1.0, correct:True
# pred:0.9748898148536682,label:1.0, correct:True
# pred:0.0023374720476567745,label:0.0, correct:True
# pred:0.003942504990845919,label:0.0, correct:True
# pred:0.99440598487854,label:1.0, correct:True
# pred:0.9973798394203186,label:1.0, correct:True
# pred:0.9954046010971069,label:1.0, correct:True
# pred:0.0023532272316515446,label:0.0, correct:True
# pred:0.006401018239557743,label:0.0, correct:True
# pred:0.00016136876365635544,label:0.0, correct:True
# pred:0.00956296268850565,label:0.0, correct:True
# pred:0.9967819452285767,label:1.0, correct:True
# pred:0.003037744201719761,label:0.0, correct:True
# pred:0.9926282167434692,label:1.0, correct:True
# pred:0.000711801287252456,label:0.0, correct:True
# pred:0.9928459525108337,label:1.0, correct:True
# pred:0.003025101264938712,label:0.0, correct:True
# pred:0.003456347156316042,label:0.0, correct:True
# pred:0.7764933109283447,label:1.0, correct:True
# pred:0.9997937083244324,label:1.0, correct:True
# pred:0.006344519555568695,label:0.0, correct:True
# pred:0.9976615905761719,label:1.0, correct:True
# pred:0.0077912225387990475,label:0.0, correct:True
# pred:0.017268257215619087,label:0.0, correct:True
# pred:0.006353508215397596,label:0.0, correct:True
# pred:0.99983811378479,label:1.0, correct:True
# pred:0.014815876260399818,label:0.0, correct:True
# pred:0.006096776574850082,label:0.0, correct:True
# pred:0.9893022179603577,label:1.0, correct:True
# pred:0.002366737462580204,label:0.0, correct:True
# pred:0.003170938463881612,label:0.0, correct:True
# pred:0.9952067732810974,label:1.0, correct:True
# pred:0.9864285588264465,label:1.0, correct:True
# pred:0.0003165404195897281,label:0.0, correct:True
# pred:0.9992347955703735,label:1.0, correct:True
# pred:0.9951304197311401,label:1.0, correct:True
# pred:0.000803125265520066,label:0.0, correct:True
# pred:0.9976217150688171,label:1.0, correct:True
# pred:0.9803948402404785,label:1.0, correct:True
# pred:0.9941237568855286,label:1.0, correct:True
# pred:0.9971068501472473,label:1.0, correct:True
# pred:0.9962132573127747,label:1.0, correct:True
# pred:0.9997003078460693,label:1.0, correct:True
# pred:5.436262290459126e-05,label:0.0, correct:True
# pred:0.006272963248193264,label:0.0, correct:True
# pred:0.9965916872024536,label:1.0, correct:True
# pred:0.009121318347752094,label:0.0, correct:True
# pred:0.9889003038406372,label:1.0, correct:True
# pred:0.9983056783676147,label:1.0, correct:True
# pred:0.008476963266730309,label:0.0, correct:True
# pred:0.00017021321400534362,label:0.0, correct:True
# pred:0.9893590211868286,label:1.0, correct:True
# pred:0.00015768340381328017,label:0.0, correct:True
# pred:0.003558464115485549,label:0.0, correct:True
# pred:0.97409987449646,label:1.0, correct:True
# pred:0.9995606541633606,label:1.0, correct:True
# pred:0.0003288098960183561,label:0.0, correct:True
# pred:0.003974710125476122,label:0.0, correct:True
# pred:0.00545978220179677,label:0.0, correct:True
# pred:0.0007470388081856072,label:0.0, correct:True
# pred:0.9984233379364014,label:1.0, correct:True
# pred:0.9965246319770813,label:1.0, correct:True
# pred:0.9997816681861877,label:1.0, correct:True
# pred:0.0034973742440342903,label:0.0, correct:True
# pred:0.9957483410835266,label:1.0, correct:True
# pred:0.00013553242024499923,label:0.0, correct:True
# pred:0.9970230460166931,label:1.0, correct:True
# pred:0.9973969459533691,label:1.0, correct:True
# pred:0.9932015538215637,label:1.0, correct:True
# pred:0.0015061557060107589,label:0.0, correct:True
# pred:0.9970537424087524,label:1.0, correct:True
# pred:0.99404376745224,label:1.0, correct:True
# pred:6.137789023341611e-05,label:0.0, correct:True
# pred:0.9887039065361023,label:1.0, correct:True
# pred:0.035085659474134445,label:0.0, correct:True
# pred:0.009467643685638905,label:0.0, correct:True
# pred:0.0038673460949212313,label:0.0, correct:True
# pred:0.991262674331665,label:1.0, correct:True
# pred:0.9992638230323792,label:1.0, correct:True
# pred:0.9997026324272156,label:1.0, correct:True
# pred:0.137104794383049,label:0.0, correct:True
# pred:0.89581298828125,label:1.0, correct:True
# pred:0.00473258551210165,label:0.0, correct:True
# pred:0.9973552227020264,label:1.0, correct:True
# pred:0.9988957643508911,label:1.0, correct:True
# pred:0.9978917241096497,label:1.0, correct:True
# pred:0.007975894026458263,label:0.0, correct:True
# pred:0.0011448446894064546,label:0.0, correct:True
# pred:0.002337054116651416,label:0.0, correct:True
# pred:0.011246485635638237,label:0.0, correct:True
# pred:0.024172823876142502,label:0.0, correct:True
# pred:0.0028452302794903517,label:0.0, correct:True
# pred:0.9978912472724915,label:1.0, correct:True
# pred:0.9855833053588867,label:1.0, correct:True
# pred:0.996025562286377,label:1.0, correct:True
# pred:0.8811051845550537,label:1.0, correct:True
# pred:0.9288438558578491,label:1.0, correct:True
# pred:0.5203485488891602,label:0.0, correct:False
# pred:0.9866647720336914,label:0.0, correct:False
# pred:0.9998935461044312,label:1.0, correct:True
# pred:0.9141366481781006,label:1.0, correct:True
# pred:0.9996886253356934,label:1.0, correct:True
# pred:0.009474514983594418,label:0.0, correct:True
# pred:0.9952400922775269,label:1.0, correct:True
# pred:0.024623775854706764,label:0.0, correct:True
# pred:0.0037966351956129074,label:0.0, correct:True
# pred:0.9988914132118225,label:1.0, correct:True
# pred:0.999596893787384,label:1.0, correct:True
# pred:0.007030521985143423,label:0.0, correct:True
# pred:0.06869900971651077,label:0.0, correct:True
# pred:0.017605915665626526,label:0.0, correct:True
# pred:0.9904986023902893,label:1.0, correct:True
# pred:0.00011194402031833306,label:0.0, correct:True
# pred:0.9849660396575928,label:1.0, correct:True
# pred:0.004575937986373901,label:0.0, correct:True
# pred:0.013768214732408524,label:0.0, correct:True
# pred:8.602624438935891e-05,label:0.0, correct:True
# pred:0.9916757345199585,label:1.0, correct:True
# pred:0.000794404128100723,label:0.0, correct:True
# pred:0.9983731508255005,label:1.0, correct:True
# pred:0.9995736479759216,label:1.0, correct:True
# pred:0.004088403657078743,label:0.0, correct:True
# pred:0.007936349138617516,label:0.0, correct:True
# pred:0.9966909885406494,label:1.0, correct:True
# pred:0.027057411149144173,label:0.0, correct:True
# pred:0.99454665184021,label:1.0, correct:True
# pred:0.9975513815879822,label:1.0, correct:True
# pred:0.0006896029808558524,label:0.0, correct:True
# pred:0.004070841241627932,label:0.0, correct:True
# pred:0.9648202061653137,label:1.0, correct:True
# pred:0.9906921982765198,label:1.0, correct:True
# pred:0.007348719518631697,label:0.0, correct:True
# pred:0.0009276146884076297,label:0.0, correct:True
# pred:0.9949817061424255,label:1.0, correct:True
# pred:0.9968762397766113,label:1.0, correct:True
# pred:0.9999011754989624,label:1.0, correct:True
# pred:0.9995502829551697,label:1.0, correct:True
# pred:0.9996572732925415,label:1.0, correct:True
# pred:0.9965698719024658,label:1.0, correct:True
# pred:0.9970734119415283,label:1.0, correct:True
# pred:0.0025615908671170473,label:0.0, correct:True
# pred:0.9980335831642151,label:1.0, correct:True
# pred:0.999812662601471,label:1.0, correct:True
# pred:0.008682943880558014,label:0.0, correct:True
# pred:0.9978078007698059,label:1.0, correct:True
# pred:0.0022530227433890104,label:0.0, correct:True
# pred:0.012904980219900608,label:0.0, correct:True
# pred:0.9967735409736633,label:1.0, correct:True
# pred:0.9940059185028076,label:1.0, correct:True
# pred:0.9934353828430176,label:1.0, correct:True
# pred:0.9880657196044922,label:1.0, correct:True
# pred:0.995704710483551,label:1.0, correct:True
# pred:4.1209172195522115e-05,label:0.0, correct:True
# pred:0.0044606528244912624,label:0.0, correct:True
# pred:0.9986557960510254,label:1.0, correct:True
# pred:0.995459258556366,label:1.0, correct:True
# pred:0.998837411403656,label:1.0, correct:True
# pred:0.9926413893699646,label:1.0, correct:True
# pred:0.9996236562728882,label:1.0, correct:True
# pred:0.999713122844696,label:1.0, correct:True
# pred:0.0001093096288968809,label:0.0, correct:True
# pred:0.9771643280982971,label:1.0, correct:True
# pred:0.9975873231887817,label:1.0, correct:True
# pred:0.9994186162948608,label:1.0, correct:True
# pred:0.004620127379894257,label:0.0, correct:True
# pred:0.9920068383216858,label:1.0, correct:True
# pred:0.0011210343800485134,label:0.0, correct:True
# pred:0.9320594668388367,label:1.0, correct:True
# pred:0.898609459400177,label:1.0, correct:True
# pred:9.19289086596109e-05,label:0.0, correct:True
# pred:0.9998898506164551,label:1.0, correct:True
# pred:0.999119222164154,label:1.0, correct:True
# pred:0.028262294828891754,label:0.0, correct:True
# pred:0.00029028812423348427,label:0.0, correct:True
# pred:0.9947189092636108,label:1.0, correct:True
# pred:0.9976661205291748,label:1.0, correct:True
# pred:0.005301308818161488,label:0.0, correct:True
# pred:0.003138978034257889,label:0.0, correct:True
# pred:0.9040830731391907,label:1.0, correct:True
# pred:0.95790034532547,label:1.0, correct:True
# pred:0.004312511067837477,label:0.0, correct:True
# pred:0.9702945947647095,label:1.0, correct:True
# pred:0.014695331454277039,label:0.0, correct:True
# pred:0.9966784715652466,label:1.0, correct:True
# pred:0.9990222454071045,label:1.0, correct:True
# pred:0.997657060623169,label:1.0, correct:True
# pred:0.9966425895690918,label:1.0, correct:True
# pred:0.003874273970723152,label:0.0, correct:True
# pred:0.003515725489705801,label:0.0, correct:True
# pred:0.9967355132102966,label:1.0, correct:True
# pred:0.9278897643089294,label:1.0, correct:True
# pred:0.9992958307266235,label:1.0, correct:True
# pred:0.9935367703437805,label:1.0, correct:True
# pred:0.9959970712661743,label:1.0, correct:True
# pred:0.9740455746650696,label:1.0, correct:True
# pred:0.9997053742408752,label:1.0, correct:True
# pred:0.00013618468074128032,label:0.0, correct:True
# pred:0.9984956979751587,label:1.0, correct:True
# pred:0.9969832301139832,label:1.0, correct:True
# pred:1.990352939174045e-05,label:0.0, correct:True
# pred:0.9879097938537598,label:1.0, correct:True
# pred:0.9923335313796997,label:1.0, correct:True
# pred:0.9463035464286804,label:1.0, correct:True
# pred:0.9993923902511597,label:1.0, correct:True
# pred:0.9945231676101685,label:1.0, correct:True
# pred:0.9861582517623901,label:1.0, correct:True
# pred:0.9829663038253784,label:1.0, correct:True
# pred:0.9880141615867615,label:1.0, correct:True
# pred:0.005741607863456011,label:0.0, correct:True
# pred:0.053594984114170074,label:0.0, correct:True
# pred:0.9825862646102905,label:1.0, correct:True
# pred:0.007363626267760992,label:0.0, correct:True
# pred:0.9968512654304504,label:1.0, correct:True
# pred:0.994243323802948,label:1.0, correct:True
# pred:0.9689688086509705,label:1.0, correct:True
# pred:0.0019688161555677652,label:0.0, correct:True
# pred:0.06830205023288727,label:0.0, correct:True
# pred:0.9972667694091797,label:1.0, correct:True
# pred:0.01086450181901455,label:0.0, correct:True
# pred:0.00042321631917729974,label:0.0, correct:True
# pred:0.9996715784072876,label:1.0, correct:True
# pred:0.9997255206108093,label:1.0, correct:True
# pred:0.004393979907035828,label:0.0, correct:True
# pred:0.9735018610954285,label:1.0, correct:True
# pred:0.005261164158582687,label:0.0, correct:True
# pred:0.9983397722244263,label:1.0, correct:True
# pred:0.0013814884005114436,label:0.0, correct:True
# pred:0.9868059158325195,label:1.0, correct:True
# pred:0.9966471791267395,label:1.0, correct:True
# pred:0.9961502552032471,label:1.0, correct:True
# pred:0.9963059425354004,label:1.0, correct:True
# pred:0.05354851484298706,label:0.0, correct:True
# pred:0.9991004467010498,label:1.0, correct:True
# pred:0.9999037981033325,label:1.0, correct:True
# pred:0.9942625164985657,label:1.0, correct:True
# pred:0.9986560344696045,label:1.0, correct:True
# pred:0.002391069894656539,label:0.0, correct:True
# pred:0.004180994816124439,label:0.0, correct:True
# pred:0.9994263648986816,label:1.0, correct:True
# pred:0.9925193786621094,label:1.0, correct:True
# pred:0.99562007188797,label:1.0, correct:True
# pred:0.962184488773346,label:1.0, correct:True
# pred:0.00349038140848279,label:0.0, correct:True
# pred:0.9839878082275391,label:1.0, correct:True
# pred:0.010629518888890743,label:0.0, correct:True
# pred:0.9982717037200928,label:1.0, correct:True
# pred:0.9997958540916443,label:1.0, correct:True
# pred:0.9929666519165039,label:1.0, correct:True
# pred:0.9670087099075317,label:1.0, correct:True
# pred:0.8740999698638916,label:1.0, correct:True
# pred:0.0003751629265025258,label:0.0, correct:True
# pred:0.9973784685134888,label:1.0, correct:True
# pred:0.448430597782135,label:0.0, correct:True
# pred:0.9992827773094177,label:1.0, correct:True
# pred:0.9986979961395264,label:1.0, correct:True
# pred:0.8931600451469421,label:1.0, correct:True
# pred:0.9932477474212646,label:1.0, correct:True
# pred:0.005470024421811104,label:0.0, correct:True
# pred:0.0008462294354103506,label:0.0, correct:True
# pred:0.9988359808921814,label:1.0, correct:True
# pred:0.021930070593953133,label:0.0, correct:True
# pred:0.0033056114334613085,label:0.0, correct:True
# pred:0.9997419714927673,label:1.0, correct:True
# pred:0.0031413903925567865,label:0.0, correct:True
# pred:0.9926618337631226,label:1.0, correct:True
# pred:0.9977703094482422,label:1.0, correct:True
# pred:9.489625517744571e-05,label:0.0, correct:True
# pred:0.007893350906670094,label:0.0, correct:True
# pred:0.9897348880767822,label:1.0, correct:True
# pred:0.0022448142990469933,label:0.0, correct:True
# pred:0.015541196800768375,label:0.0, correct:True
# pred:0.006346479989588261,label:0.0, correct:True
# pred:0.007335219066590071,label:0.0, correct:True
# pred:0.999025821685791,label:1.0, correct:True
# pred:0.15583489835262299,label:0.0, correct:True
# pred:0.9941959381103516,label:1.0, correct:True
# pred:0.9829980134963989,label:1.0, correct:True
# pred:1.5618772522429936e-05,label:0.0, correct:True
# pred:0.005988919176161289,label:0.0, correct:True
# pred:0.9323927760124207,label:1.0, correct:True
# pred:0.9967027306556702,label:1.0, correct:True
# pred:0.9972865581512451,label:1.0, correct:True
# pred:0.003951983992010355,label:0.0, correct:True
# pred:0.007951862178742886,label:0.0, correct:True
# pred:0.9971711039543152,label:1.0, correct:True
# pred:0.9982733726501465,label:1.0, correct:True
# pred:0.9881287217140198,label:1.0, correct:True
# pred:0.9883530735969543,label:1.0, correct:True
# pred:0.9999332427978516,label:1.0, correct:True
# pred:0.9813866019248962,label:1.0, correct:True
# pred:0.005283190403133631,label:0.0, correct:True
# pred:0.998016357421875,label:1.0, correct:True
# pred:0.9998669624328613,label:1.0, correct:True
# pred:0.9994296431541443,label:1.0, correct:True
# pred:0.9983524084091187,label:1.0, correct:True
# pred:0.9906190633773804,label:1.0, correct:True
# pred:0.003321742406114936,label:0.0, correct:True
# pred:0.05140874162316322,label:0.0, correct:True
# pred:3.2557014492340386e-05,label:0.0, correct:True
# pred:0.9961318969726562,label:1.0, correct:True
# pred:0.7820567488670349,label:1.0, correct:True
# pred:0.9989786148071289,label:1.0, correct:True
# pred:0.0049886442720890045,label:0.0, correct:True
# pred:0.9999064207077026,label:1.0, correct:True
# pred:6.125988875282928e-05,label:0.0, correct:True
# pred:0.9963515996932983,label:1.0, correct:True
# pred:0.001821135520003736,label:0.0, correct:True
# pred:0.00757781183347106,label:0.0, correct:True
# pred:0.9833301901817322,label:1.0, correct:True
# pred:0.0002341612707823515,label:0.0, correct:True
# pred:0.0012118725571781397,label:0.0, correct:True
# pred:0.9986720085144043,label:1.0, correct:True
# pred:0.0011387645499780774,label:0.0, correct:True
# pred:0.9997578263282776,label:1.0, correct:True
# pred:0.0035600655246526003,label:0.0, correct:True
# pred:0.9951435327529907,label:1.0, correct:True
# pred:0.056725747883319855,label:0.0, correct:True
# pred:0.002719960641115904,label:0.0, correct:True
# pred:0.997648298740387,label:1.0, correct:True
# pred:0.9832760095596313,label:1.0, correct:True
# pred:0.9955620765686035,label:1.0, correct:True
# pred:0.977348804473877,label:1.0, correct:True
# pred:6.998410299274838e-06,label:0.0, correct:True
# pred:0.0033920619171112776,label:0.0, correct:True
# pred:0.006180749274790287,label:0.0, correct:True
# pred:6.581981142517179e-05,label:0.0, correct:True
# pred:0.9973335266113281,label:1.0, correct:True
# pred:0.9926757216453552,label:1.0, correct:True
# pred:0.9826545119285583,label:1.0, correct:True
# pred:0.997266411781311,label:1.0, correct:True
# pred:0.9961580634117126,label:1.0, correct:True
# pred:0.010387574322521687,label:0.0, correct:True
# pred:0.0026233415119349957,label:0.0, correct:True
# pred:0.008440549485385418,label:0.0, correct:True
# pred:0.8728270530700684,label:1.0, correct:True
# pred:0.9980237483978271,label:1.0, correct:True
# pred:0.9993700385093689,label:1.0, correct:True
# pred:0.002107470529153943,label:0.0, correct:True
# pred:0.9825311303138733,label:1.0, correct:True
# pred:4.2774998291861266e-05,label:0.0, correct:True
# pred:0.9965512752532959,label:1.0, correct:True
# pred:0.7711499929428101,label:1.0, correct:True
# pred:5.05103926116135e-05,label:0.0, correct:True
# pred:0.9284510612487793,label:1.0, correct:True
# pred:0.0043480489403009415,label:0.0, correct:True
# pred:0.010433466173708439,label:0.0, correct:True
# pred:0.9959108829498291,label:1.0, correct:True
# pred:0.9989847540855408,label:1.0, correct:True
# pred:0.9964424967765808,label:1.0, correct:True
# pred:0.9968558549880981,label:1.0, correct:True
# pred:0.9937735795974731,label:1.0, correct:True
# pred:0.013552621938288212,label:0.0, correct:True
# pred:0.9971279501914978,label:1.0, correct:True
# pred:0.992558479309082,label:1.0, correct:True
# pred:0.9950942993164062,label:1.0, correct:True
# pred:0.15672755241394043,label:1.0, correct:False
# pred:7.244786684168503e-05,label:0.0, correct:True
# pred:0.9974834322929382,label:1.0, correct:True
# pred:0.0037960761692374945,label:0.0, correct:True
# pred:0.005271045491099358,label:0.0, correct:True
# pred:0.9969973564147949,label:1.0, correct:True
# pred:0.003175359219312668,label:0.0, correct:True
# pred:0.9990690350532532,label:1.0, correct:True
# pred:0.9964784979820251,label:1.0, correct:True
# pred:0.008190225809812546,label:0.0, correct:True
# pred:0.9989198446273804,label:1.0, correct:True
# pred:0.9992676377296448,label:1.0, correct:True
# pred:9.665200195740908e-05,label:0.0, correct:True
# pred:0.0016053918516263366,label:0.0, correct:True
# pred:0.005121039226651192,label:0.0, correct:True
# pred:0.9932184815406799,label:1.0, correct:True
# pred:0.9220031499862671,label:0.0, correct:False
# pred:0.8734527826309204,label:1.0, correct:True
# pred:0.0031086611561477184,label:0.0, correct:True
# pred:0.9984412789344788,label:1.0, correct:True
# pred:0.9933558702468872,label:1.0, correct:True
# pred:0.009189529344439507,label:0.0, correct:True
# pred:0.9917359948158264,label:1.0, correct:True
# pred:0.0006921394960954785,label:0.0, correct:True
# pred:0.3989087641239166,label:1.0, correct:False
# pred:0.0036471823696047068,label:0.0, correct:True
# pred:0.003152368124574423,label:0.0, correct:True
# pred:0.9885210990905762,label:1.0, correct:True
# pred:0.9985812902450562,label:1.0, correct:True
# pred:0.006579719018191099,label:0.0, correct:True
# pred:0.0001247091277036816,label:0.0, correct:True
# pred:0.9997829794883728,label:1.0, correct:True
# pred:0.0005426063435152173,label:0.0, correct:True
# pred:0.00016140923253260553,label:0.0, correct:True
# pred:0.12000798434019089,label:0.0, correct:True
# pred:0.006276377011090517,label:0.0, correct:True
# pred:2.9072267352603376e-05,label:0.0, correct:True
# pred:0.004645264241844416,label:0.0, correct:True
# pred:0.9985148310661316,label:1.0, correct:True
# pred:0.005128035321831703,label:0.0, correct:True
# pred:0.99779212474823,label:1.0, correct:True
# pred:0.002573820296674967,label:0.0, correct:True
# pred:0.038813889026641846,label:0.0, correct:True
# pred:0.996329128742218,label:1.0, correct:True
# pred:0.9799360036849976,label:1.0, correct:True
# pred:0.003854592563584447,label:0.0, correct:True
# pred:0.1894437074661255,label:0.0, correct:True
# pred:0.9975232481956482,label:1.0, correct:True
# pred:0.00010532094893278554,label:0.0, correct:True
# pred:0.9996669292449951,label:1.0, correct:True
# pred:0.00406982284039259,label:0.0, correct:True
# pred:0.999736487865448,label:1.0, correct:True
# pred:0.9960357546806335,label:1.0, correct:True
# pred:0.9727880358695984,label:1.0, correct:True
# pred:0.027397338300943375,label:0.0, correct:True
# pred:0.005667250137776136,label:0.0, correct:True
# pred:0.00041307209176011384,label:0.0, correct:True
# pred:0.99847811460495,label:1.0, correct:True
# pred:0.9978830218315125,label:1.0, correct:True
# pred:0.0032987187150865793,label:0.0, correct:True
# pred:0.0023656454868614674,label:0.0, correct:True
# pred:0.9053366780281067,label:1.0, correct:True
# pred:0.9954953193664551,label:1.0, correct:True
# pred:0.865943431854248,label:1.0, correct:True
# pred:0.995928943157196,label:1.0, correct:True
# pred:0.007024290040135384,label:0.0, correct:True
# pred:0.9966887831687927,label:1.0, correct:True
# pred:0.9991967082023621,label:1.0, correct:True
# pred:0.005561084020882845,label:0.0, correct:True
# pred:0.9981497526168823,label:1.0, correct:True
# pred:0.9959656000137329,label:1.0, correct:True
# pred:0.0045539927668869495,label:0.0, correct:True
# pred:0.9789001941680908,label:1.0, correct:True
# pred:0.9997084736824036,label:1.0, correct:True
# pred:0.24138225615024567,label:0.0, correct:True
# pred:0.9994878768920898,label:1.0, correct:True
# pred:0.9894573092460632,label:1.0, correct:True
# pred:0.9991151690483093,label:1.0, correct:True
# pred:0.9973437190055847,label:1.0, correct:True
# pred:0.9993405938148499,label:1.0, correct:True
# pred:0.9252923727035522,label:1.0, correct:True
# pred:0.00049853470409289,label:0.0, correct:True
# pred:0.9983892440795898,label:1.0, correct:True
# pred:0.01273104827851057,label:0.0, correct:True
# pred:0.0029534720815718174,label:0.0, correct:True
# pred:0.9977941513061523,label:1.0, correct:True
# pred:9.57325246417895e-05,label:0.0, correct:True
# pred:0.6746264100074768,label:0.0, correct:False
# pred:0.00014427912537939847,label:0.0, correct:True
# pred:0.010679803788661957,label:0.0, correct:True
# pred:0.004697770345956087,label:0.0, correct:True
# pred:0.995805025100708,label:1.0, correct:True
# pred:0.7931057214736938,label:1.0, correct:True
# pred:0.003030889667570591,label:0.0, correct:True
# pred:0.9965652823448181,label:1.0, correct:True
# pred:0.9995668530464172,label:1.0, correct:True
# pred:0.9982035160064697,label:1.0, correct:True
# pred:0.005770750809460878,label:0.0, correct:True
# pred:0.00023247039644047618,label:0.0, correct:True
# pred:2.2659145543002523e-05,label:0.0, correct:True
# pred:0.9995939135551453,label:1.0, correct:True
# pred:0.0073402272537350655,label:0.0, correct:True
# pred:0.9930746555328369,label:1.0, correct:True
# pred:0.005352567415684462,label:0.0, correct:True
# pred:0.9911744594573975,label:1.0, correct:True
# pred:0.9977729916572571,label:1.0, correct:True
# pred:0.0027072394732385874,label:0.0, correct:True
# pred:0.9946633577346802,label:0.0, correct:False
# pred:0.9980790615081787,label:1.0, correct:True
# pred:0.004103657323867083,label:0.0, correct:True
# pred:0.0007964107790030539,label:0.0, correct:True
# pred:0.9750801920890808,label:1.0, correct:True
# pred:0.002735401503741741,label:0.0, correct:True
# pred:0.9682289958000183,label:1.0, correct:True
# pred:0.00016114026948343962,label:0.0, correct:True
# pred:0.998428225517273,label:1.0, correct:True
# pred:0.9994183778762817,label:1.0, correct:True
# pred:0.9939166903495789,label:1.0, correct:True
# pred:0.9960071444511414,label:1.0, correct:True
# pred:0.0020443606190383434,label:0.0, correct:True
# pred:0.994709849357605,label:1.0, correct:True
# pred:9.559830687067006e-06,label:0.0, correct:True
# pred:0.9989129304885864,label:1.0, correct:True
# pred:0.998289167881012,label:1.0, correct:True
# pred:0.9994731545448303,label:1.0, correct:True
# pred:0.9997251629829407,label:1.0, correct:True
# pred:0.03606662526726723,label:0.0, correct:True
# pred:0.9959243535995483,label:1.0, correct:True
# pred:0.005099066067487001,label:0.0, correct:True
# pred:0.9987993240356445,label:1.0, correct:True
# pred:0.9986444115638733,label:1.0, correct:True
# pred:0.01711442694067955,label:0.0, correct:True
# pred:0.0074513801373541355,label:0.0, correct:True
# pred:0.9993070363998413,label:1.0, correct:True
# pred:0.017783379182219505,label:0.0, correct:True
# pred:0.9997707009315491,label:1.0, correct:True
# pred:0.9960508942604065,label:1.0, correct:True
# pred:0.011723306030035019,label:0.0, correct:True
# pred:0.002375022741034627,label:0.0, correct:True
# pred:0.003611336462199688,label:0.0, correct:True
# pred:0.009259155951440334,label:0.0, correct:True
# pred:0.999786913394928,label:1.0, correct:True
# pred:0.000153578061144799,label:0.0, correct:True
# pred:0.0072075012139976025,label:0.0, correct:True
# pred:0.004086000844836235,label:0.0, correct:True
# pred:0.00012349839380476624,label:0.0, correct:True
# pred:0.9996090531349182,label:1.0, correct:True
# pred:0.9971030354499817,label:1.0, correct:True
# pred:0.9997772574424744,label:1.0, correct:True
# pred:0.005717153195291758,label:0.0, correct:True
# pred:0.9994174242019653,label:1.0, correct:True
# pred:0.001556895556859672,label:0.0, correct:True
# pred:0.9979426264762878,label:1.0, correct:True
# pred:0.9988734126091003,label:1.0, correct:True
# pred:0.9881793260574341,label:1.0, correct:True
# pred:0.006339706014841795,label:0.0, correct:True
# pred:0.00327465683221817,label:0.0, correct:True
# pred:0.00017653645772952586,label:0.0, correct:True
# pred:0.9929942488670349,label:1.0, correct:True
# pred:0.9966152310371399,label:1.0, correct:True
# pred:0.0027049656491726637,label:0.0, correct:True
# pred:0.9995099306106567,label:1.0, correct:True
# pred:0.9941807389259338,label:1.0, correct:True
# pred:0.005972995422780514,label:0.0, correct:True
# pred:0.9863980412483215,label:1.0, correct:True
# pred:0.9966263771057129,label:1.0, correct:True
# pred:0.0030981574673205614,label:0.0, correct:True
# pred:0.9980046153068542,label:1.0, correct:True
# pred:0.9980669617652893,label:1.0, correct:True
# pred:0.9846211671829224,label:1.0, correct:True
# pred:0.005591433495283127,label:0.0, correct:True
# pred:0.9966416358947754,label:1.0, correct:True
# pred:0.9942238926887512,label:1.0, correct:True
# pred:0.004784892778843641,label:0.0, correct:True
# pred:0.00034688549931161106,label:0.0, correct:True
# pred:0.9997143149375916,label:1.0, correct:True
# pred:0.0003569660475477576,label:0.0, correct:True
# pred:0.9878420829772949,label:1.0, correct:True
# pred:0.00011097121750935912,label:0.0, correct:True
# pred:0.9998100399971008,label:1.0, correct:True
# pred:0.002628799295052886,label:0.0, correct:True
# pred:0.9982129335403442,label:1.0, correct:True
# pred:1.816711483115796e-05,label:0.0, correct:True
# pred:0.9976713061332703,label:1.0, correct:True
# pred:0.9985108971595764,label:1.0, correct:True
# pred:0.9993226528167725,label:1.0, correct:True
# pred:0.9926139116287231,label:1.0, correct:True
# pred:0.9960182309150696,label:1.0, correct:True
# pred:0.9978851675987244,label:1.0, correct:True
# pred:0.02116941660642624,label:0.0, correct:True
# pred:0.9972648620605469,label:1.0, correct:True
# pred:0.004509683232754469,label:0.0, correct:True
# pred:0.993990421295166,label:1.0, correct:True
# pred:0.000990484724752605,label:0.0, correct:True
# pred:0.9903134107589722,label:1.0, correct:True
# pred:0.003375417087227106,label:0.0, correct:True
# pred:0.9920982122421265,label:1.0, correct:True
# pred:0.9998223185539246,label:1.0, correct:True
# pred:0.0032332635018974543,label:0.0, correct:True
# pred:0.992133378982544,label:1.0, correct:True
# pred:0.0056217689998447895,label:0.0, correct:True
# pred:0.0023289809469133615,label:0.0, correct:True
# pred:0.9996848106384277,label:1.0, correct:True
# pred:0.0019344405736774206,label:0.0, correct:True
# pred:0.9929357171058655,label:1.0, correct:True
# pred:0.9617266654968262,label:1.0, correct:True
# pred:0.9953786134719849,label:1.0, correct:True
# pred:0.002123851329088211,label:0.0, correct:True
# pred:0.35485604405403137,label:1.0, correct:False
# pred:5.304988007992506e-05,label:0.0, correct:True
# pred:0.9988083839416504,label:1.0, correct:True
# pred:0.0033091071527451277,label:0.0, correct:True
# pred:0.9986701011657715,label:1.0, correct:True
# pred:0.9937275648117065,label:1.0, correct:True
# pred:0.0017923273844644427,label:0.0, correct:True
# pred:0.0053320941515266895,label:0.0, correct:True
# pred:0.005448135081678629,label:0.0, correct:True
# pred:0.9990944862365723,label:1.0, correct:True
# pred:0.00028298539109528065,label:0.0, correct:True
# pred:0.994789719581604,label:1.0, correct:True
# pred:0.004962482955306768,label:0.0, correct:True
# pred:0.9922571182250977,label:1.0, correct:True
# pred:0.0033919408451765776,label:0.0, correct:True
# pred:0.9898899793624878,label:1.0, correct:True
# pred:0.9755002856254578,label:1.0, correct:True
# pred:0.5900174379348755,label:1.0, correct:True
# pred:0.00011604907922446728,label:0.0, correct:True
# pred:0.000433410401456058,label:0.0, correct:True
# pred:0.9996626377105713,label:1.0, correct:True
# pred:0.9991687536239624,label:1.0, correct:True
# pred:0.9975078105926514,label:1.0, correct:True
# pred:0.9818080067634583,label:1.0, correct:True
# pred:0.9987820982933044,label:1.0, correct:True
# pred:0.9981803894042969,label:1.0, correct:True
# pred:0.9824417233467102,label:1.0, correct:True
# pred:0.9225462675094604,label:0.0, correct:False
# pred:0.7022058963775635,label:1.0, correct:True
# pred:0.9985682964324951,label:1.0, correct:True
# pred:0.0063474480994045734,label:0.0, correct:True
# pred:0.9996167421340942,label:1.0, correct:True
# pred:0.003296023001894355,label:0.0, correct:True
# pred:0.005525162909179926,label:0.0, correct:True
# pred:0.9975079298019409,label:1.0, correct:True
# pred:5.735241575166583e-05,label:0.0, correct:True
# pred:0.9993947744369507,label:1.0, correct:True
# pred:0.9997746348381042,label:1.0, correct:True
# pred:0.9976814985275269,label:1.0, correct:True
# pred:0.9990683197975159,label:1.0, correct:True
# pred:0.9638185501098633,label:1.0, correct:True
# pred:0.001826154999434948,label:0.0, correct:True
# pred:6.918797589605674e-05,label:0.0, correct:True
# pred:6.503585609607399e-05,label:0.0, correct:True
# pred:8.027495641727e-05,label:0.0, correct:True
# pred:0.07115184515714645,label:0.0, correct:True
# pred:0.0004165216814726591,label:0.0, correct:True
# pred:0.9962655901908875,label:1.0, correct:True
# pred:0.01327860914170742,label:0.0, correct:True
# pred:0.0023337577003985643,label:0.0, correct:True
# pred:0.9955904483795166,label:1.0, correct:True
# pred:0.9869197607040405,label:1.0, correct:True
# pred:0.00346600660122931,label:0.0, correct:True
# pred:0.012273414060473442,label:0.0, correct:True
# pred:0.006806190591305494,label:0.0, correct:True
# pred:0.8285742402076721,label:1.0, correct:True
# pred:0.9964424967765808,label:1.0, correct:True
# pred:4.375506250653416e-05,label:0.0, correct:True
# pred:0.0035749906674027443,label:0.0, correct:True
# pred:0.9989669322967529,label:1.0, correct:True
# pred:0.9923037886619568,label:1.0, correct:True
# pred:0.9987866282463074,label:1.0, correct:True
# pred:0.999545156955719,label:1.0, correct:True
# pred:0.9982615113258362,label:1.0, correct:True
# pred:0.03492146357893944,label:0.0, correct:True
# pred:0.0013827375369146466,label:0.0, correct:True
# pred:0.9996320009231567,label:1.0, correct:True
# pred:0.006480255164206028,label:0.0, correct:True
# pred:0.004031796008348465,label:0.0, correct:True
# pred:0.9549624919891357,label:1.0, correct:True
# pred:0.9973662495613098,label:1.0, correct:True
# pred:0.0026018894277513027,label:0.0, correct:True
# pred:0.9994964599609375,label:1.0, correct:True
# pred:0.0011050570756196976,label:0.0, correct:True
# pred:0.9929676055908203,label:1.0, correct:True
# pred:0.9918547868728638,label:1.0, correct:True
# pred:0.005386687815189362,label:0.0, correct:True
# pred:0.0069380695931613445,label:0.0, correct:True
# pred:0.9532500505447388,label:1.0, correct:True
# pred:0.9979568719863892,label:1.0, correct:True
# pred:0.0038748534861952066,label:0.0, correct:True
# pred:0.994102418422699,label:1.0, correct:True
# pred:0.0005493600619956851,label:0.0, correct:True
# pred:0.007061657961457968,label:0.0, correct:True
# accuracy: 0.9817470664928292

# %%
model1 = torch.load("./model_old.pt")
model1.eval()
correct = 0
with torch.no_grad():
    for inputs, labels in testloader:
        inputs = inputs.to(device)
        labels = labels.to(device)
        outputs = model1(inputs.to(device))
        # print(outputs.view(-1))
        for i in range(len(outputs.detach().numpy().round())):
            print("pred:{},label:{}, correct:{}".format(outputs.detach().numpy()[i][0],labels.detach().numpy()[i],outputs.detach().numpy().round()[i][0]==labels.detach().numpy()[i]))
            if outputs.detach().numpy().round()[i][0]==labels.detach().numpy()[i]:
                correct +=  1
    print('accuracy: {}'.format(correct/len(testloader.dataset)))
# Out:
# pred:0.5711843371391296,label:1.0, correct:True
# pred:0.17134639620780945,label:0.0, correct:True
# pred:0.1855345368385315,label:0.0, correct:True
# pred:0.19594837725162506,label:0.0, correct:True
# pred:0.5717763900756836,label:1.0, correct:True
# pred:0.2340906411409378,label:0.0, correct:True
# pred:0.5712940692901611,label:1.0, correct:True
# pred:0.571761965751648,label:1.0, correct:True
# pred:0.19879205524921417,label:0.0, correct:True
# pred:0.4566923975944519,label:0.0, correct:True
# pred:0.5717451572418213,label:1.0, correct:True
# pred:0.17292973399162292,label:0.0, correct:True
# pred:0.500709593296051,label:0.0, correct:False
# pred:0.4975651502609253,label:0.0, correct:True
# pred:0.19486768543720245,label:0.0, correct:True
# pred:0.5593975186347961,label:0.0, correct:False
# pred:0.5071094036102295,label:1.0, correct:True
# pred:0.4968653917312622,label:0.0, correct:True
# pred:0.4987078905105591,label:0.0, correct:True
# pred:0.5714699625968933,label:1.0, correct:True
# pred:0.571524977684021,label:1.0, correct:True
# pred:0.5525674223899841,label:1.0, correct:True
# pred:0.5012925267219543,label:0.0, correct:False
# pred:0.5025244355201721,label:0.0, correct:False
# pred:0.5719008445739746,label:1.0, correct:True
# pred:0.5718372464179993,label:1.0, correct:True
# pred:0.4137197434902191,label:0.0, correct:True
# pred:0.18217454850673676,label:0.0, correct:True
# pred:0.5706725716590881,label:1.0, correct:True
# pred:0.5210573077201843,label:1.0, correct:True
# pred:0.5711621642112732,label:1.0, correct:True
# pred:0.17403092980384827,label:0.0, correct:True
# pred:0.37616610527038574,label:1.0, correct:False
# pred:0.5720611214637756,label:1.0, correct:True
# pred:0.5020215511322021,label:0.0, correct:False
# pred:0.19186612963676453,label:0.0, correct:True
# pred:0.529962956905365,label:0.0, correct:False
# pred:0.3942550718784332,label:1.0, correct:False
# pred:0.5713986754417419,label:1.0, correct:True
# pred:0.5714091658592224,label:1.0, correct:True
# pred:0.5005191564559937,label:0.0, correct:False
# pred:0.20147007703781128,label:0.0, correct:True
# pred:0.2435847818851471,label:0.0, correct:True
# pred:0.5004182457923889,label:0.0, correct:False
# pred:0.5008066296577454,label:0.0, correct:False
# pred:0.571600079536438,label:1.0, correct:True
# pred:0.5717682242393494,label:0.0, correct:False
# pred:0.49132823944091797,label:1.0, correct:False
# pred:0.18785148859024048,label:0.0, correct:True
# pred:0.3956700265407562,label:0.0, correct:True
# pred:0.5514570474624634,label:0.0, correct:False
# pred:0.5720421671867371,label:1.0, correct:True
# pred:0.5702477097511292,label:1.0, correct:True
# pred:0.563964307308197,label:1.0, correct:True
# pred:0.28794610500335693,label:0.0, correct:True
# pred:0.4926876425743103,label:0.0, correct:True
# pred:0.17713512480258942,label:0.0, correct:True
# pred:0.5632449984550476,label:1.0, correct:True
# pred:0.5717527866363525,label:1.0, correct:True
# pred:0.49179619550704956,label:1.0, correct:False
# pred:0.498821884393692,label:0.0, correct:True
# pred:0.40087854862213135,label:0.0, correct:True
# pred:0.31000903248786926,label:0.0, correct:True
# pred:0.1855943202972412,label:0.0, correct:True
# pred:0.4961118698120117,label:0.0, correct:True
# pred:0.5436992049217224,label:1.0, correct:True
# pred:0.18314319849014282,label:0.0, correct:True
# pred:0.4329601526260376,label:0.0, correct:True
# pred:0.49711790680885315,label:0.0, correct:True
# pred:0.4986962080001831,label:1.0, correct:False
# pred:0.5469778180122375,label:1.0, correct:True
# pred:0.18014328181743622,label:0.0, correct:True
# pred:0.5718342065811157,label:0.0, correct:False
# pred:0.5720926523208618,label:1.0, correct:True
# pred:0.4991091191768646,label:0.0, correct:True
# pred:0.5005137324333191,label:0.0, correct:False
# pred:0.44523635506629944,label:0.0, correct:True
# pred:0.5662142634391785,label:1.0, correct:True
# pred:0.17811177670955658,label:0.0, correct:True
# pred:0.5686800479888916,label:1.0, correct:True
# pred:0.5720076560974121,label:1.0, correct:True
# pred:0.5719457268714905,label:1.0, correct:True
# pred:0.5720431804656982,label:0.0, correct:False
# pred:0.24939419329166412,label:0.0, correct:True
# pred:0.5720273852348328,label:1.0, correct:True
# pred:0.44663217663764954,label:0.0, correct:True
# pred:0.5718523263931274,label:0.0, correct:False
# pred:0.1699434369802475,label:0.0, correct:True
# pred:0.18946020305156708,label:0.0, correct:True
# pred:0.5721281170845032,label:0.0, correct:False
# pred:0.16668452322483063,label:0.0, correct:True
# pred:0.17386259138584137,label:0.0, correct:True
# pred:0.5003297924995422,label:0.0, correct:False
# pred:0.47967323660850525,label:0.0, correct:True
# pred:0.5713441371917725,label:1.0, correct:True
# pred:0.5712273120880127,label:1.0, correct:True
# pred:0.19960272312164307,label:0.0, correct:True
# pred:0.5679686069488525,label:1.0, correct:True
# pred:0.5711888670921326,label:1.0, correct:True
# pred:0.17183753848075867,label:0.0, correct:True
# pred:0.5712697505950928,label:1.0, correct:True
# pred:0.571554958820343,label:1.0, correct:True
# pred:0.5382890701293945,label:1.0, correct:True
# pred:0.49707502126693726,label:1.0, correct:False
# pred:0.5715323090553284,label:1.0, correct:True
# pred:0.5720508694648743,label:1.0, correct:True
# pred:0.40655022859573364,label:0.0, correct:True
# pred:0.5309552550315857,label:1.0, correct:True
# pred:0.4378710389137268,label:0.0, correct:True
# pred:0.5714854598045349,label:1.0, correct:True
# pred:0.17293846607208252,label:0.0, correct:True
# pred:0.5026745796203613,label:0.0, correct:False
# pred:0.5711303949356079,label:1.0, correct:True
# pred:0.4509564936161041,label:0.0, correct:True
# pred:0.18494395911693573,label:0.0, correct:True
# pred:0.5421651005744934,label:0.0, correct:False
# pred:0.5717650651931763,label:1.0, correct:True
# pred:0.5711597204208374,label:1.0, correct:True
# pred:0.17039915919303894,label:0.0, correct:True
# pred:0.18137958645820618,label:0.0, correct:True
# pred:0.5712277889251709,label:1.0, correct:True
# pred:0.5488176941871643,label:1.0, correct:True
# pred:0.3790266513824463,label:0.0, correct:True
# pred:0.18884830176830292,label:0.0, correct:True
# pred:0.5711585283279419,label:1.0, correct:True
# pred:0.5719932913780212,label:1.0, correct:True
# pred:0.5719358921051025,label:1.0, correct:True
# pred:0.18884314596652985,label:0.0, correct:True
# pred:0.17888428270816803,label:0.0, correct:True
# pred:0.5013558864593506,label:0.0, correct:False
# pred:0.18819880485534668,label:0.0, correct:True
# pred:0.5711974501609802,label:1.0, correct:True
# pred:0.17251206934452057,label:0.0, correct:True
# pred:0.5720266103744507,label:1.0, correct:True
# pred:0.23729804158210754,label:0.0, correct:True
# pred:0.5715923309326172,label:1.0, correct:True
# pred:0.17134453356266022,label:0.0, correct:True
# pred:0.17143778502941132,label:0.0, correct:True
# pred:0.4793397784233093,label:1.0, correct:False
# pred:0.5717981457710266,label:1.0, correct:True
# pred:0.38882750272750854,label:0.0, correct:True
# pred:0.4085973799228668,label:1.0, correct:False
# pred:0.2008408010005951,label:0.0, correct:True
# pred:0.23493798077106476,label:0.0, correct:True
# pred:0.1826324462890625,label:0.0, correct:True
# pred:0.5497134923934937,label:1.0, correct:True
# pred:0.2079629898071289,label:0.0, correct:True
# pred:0.1969471424818039,label:0.0, correct:True
# pred:0.571325957775116,label:1.0, correct:True
# pred:0.37219831347465515,label:0.0, correct:True
# pred:0.17847612500190735,label:0.0, correct:True
# pred:0.5716249346733093,label:1.0, correct:True
# pred:0.5720648765563965,label:1.0, correct:True
# pred:0.4997560977935791,label:0.0, correct:True
# pred:0.5274630188941956,label:1.0, correct:True
# pred:0.5716399550437927,label:1.0, correct:True
# pred:0.17369696497917175,label:0.0, correct:True
# pred:0.571978747844696,label:1.0, correct:True
# pred:0.561860978603363,label:1.0, correct:True
# pred:0.569266676902771,label:1.0, correct:True
# pred:0.5719253420829773,label:1.0, correct:True
# pred:0.5714390277862549,label:1.0, correct:True
# pred:0.5713813304901123,label:1.0, correct:True
# pred:0.49641457200050354,label:0.0, correct:True
# pred:0.19661574065685272,label:0.0, correct:True
# pred:0.5711206197738647,label:1.0, correct:True
# pred:0.2820773422718048,label:0.0, correct:True
# pred:0.5720345973968506,label:1.0, correct:True
# pred:0.5712935328483582,label:1.0, correct:True
# pred:0.19408917427062988,label:0.0, correct:True
# pred:0.497396856546402,label:0.0, correct:True
# pred:0.5716913342475891,label:1.0, correct:True
# pred:0.5009644627571106,label:0.0, correct:False
# pred:0.17250069975852966,label:0.0, correct:True
# pred:0.5445742011070251,label:1.0, correct:True
# pred:0.5720081925392151,label:1.0, correct:True
# pred:0.465850293636322,label:0.0, correct:True
# pred:0.3839899003505707,label:0.0, correct:True
# pred:0.18183325231075287,label:0.0, correct:True
# pred:0.18157503008842468,label:0.0, correct:True
# pred:0.5712451934814453,label:1.0, correct:True
# pred:0.5720171332359314,label:1.0, correct:True
# pred:0.569446325302124,label:1.0, correct:True
# pred:0.2013104110956192,label:0.0, correct:True
# pred:0.5713501572608948,label:1.0, correct:True
# pred:0.4987698197364807,label:0.0, correct:True
# pred:0.5712262392044067,label:1.0, correct:True
# pred:0.5711276531219482,label:1.0, correct:True
# pred:0.5652980804443359,label:1.0, correct:True
# pred:0.4982699155807495,label:0.0, correct:True
# pred:0.5711055397987366,label:1.0, correct:True
# pred:0.5711365342140198,label:1.0, correct:True
# pred:0.4976199269294739,label:0.0, correct:True
# pred:0.5720621347427368,label:1.0, correct:True
# pred:0.5387873649597168,label:0.0, correct:False
# pred:0.33750370144844055,label:0.0, correct:True
# pred:0.2817572355270386,label:0.0, correct:True
# pred:0.5524410009384155,label:1.0, correct:True
# pred:0.571204662322998,label:1.0, correct:True
# pred:0.5716826915740967,label:1.0, correct:True
# pred:0.5044838786125183,label:0.0, correct:False
# pred:0.4978455603122711,label:1.0, correct:False
# pred:0.17735953629016876,label:0.0, correct:True
# pred:0.5712677836418152,label:1.0, correct:True
# pred:0.5720298886299133,label:1.0, correct:True
# pred:0.5432786345481873,label:1.0, correct:True
# pred:0.18444225192070007,label:0.0, correct:True
# pred:0.2009299397468567,label:0.0, correct:True
# pred:0.17346620559692383,label:0.0, correct:True
# pred:0.4554384648799896,label:0.0, correct:True
# pred:0.24959029257297516,label:0.0, correct:True
# pred:0.4925555884838104,label:0.0, correct:True
# pred:0.5719921588897705,label:1.0, correct:True
# pred:0.5713925361633301,label:1.0, correct:True
# pred:0.5714386701583862,label:1.0, correct:True
# pred:0.3556443750858307,label:1.0, correct:False
# pred:0.5719611644744873,label:1.0, correct:True
# pred:0.5441210269927979,label:0.0, correct:False
# pred:0.5712575316429138,label:0.0, correct:False
# pred:0.5146319270133972,label:1.0, correct:True
# pred:0.496127724647522,label:1.0, correct:False
# pred:0.5653207302093506,label:1.0, correct:True
# pred:0.3152618408203125,label:0.0, correct:True
# pred:0.5711109638214111,label:1.0, correct:True
# pred:0.49720069766044617,label:0.0, correct:True
# pred:0.17226068675518036,label:0.0, correct:True
# pred:0.5087202191352844,label:1.0, correct:True
# pred:0.5714444518089294,label:1.0, correct:True
# pred:0.18886984884738922,label:0.0, correct:True
# pred:0.4966070055961609,label:0.0, correct:True
# pred:0.3286285698413849,label:0.0, correct:True
# pred:0.5714901685714722,label:1.0, correct:True
# pred:0.5000680088996887,label:0.0, correct:False
# pred:0.501194179058075,label:1.0, correct:True
# pred:0.1748988777399063,label:0.0, correct:True
# pred:0.24578134715557098,label:0.0, correct:True
# pred:0.5004248023033142,label:0.0, correct:False
# pred:0.5716204047203064,label:1.0, correct:True
# pred:0.5016463994979858,label:0.0, correct:False
# pred:0.5712857246398926,label:1.0, correct:True
# pred:0.5681252479553223,label:1.0, correct:True
# pred:0.18386441469192505,label:0.0, correct:True
# pred:0.18330025672912598,label:0.0, correct:True
# pred:0.571388840675354,label:1.0, correct:True
# pred:0.3770349323749542,label:0.0, correct:True
# pred:0.5720555186271667,label:1.0, correct:True
# pred:0.5719636082649231,label:1.0, correct:True
# pred:0.17147304117679596,label:0.0, correct:True
# pred:0.20529194176197052,label:0.0, correct:True
# pred:0.5713714361190796,label:1.0, correct:True
# pred:0.5720974802970886,label:1.0, correct:True
# pred:0.192367821931839,label:0.0, correct:True
# pred:0.3163393437862396,label:0.0, correct:True
# pred:0.5712917447090149,label:1.0, correct:True
# pred:0.5716541409492493,label:1.0, correct:True
# pred:0.5043604373931885,label:1.0, correct:True
# pred:0.5720911622047424,label:1.0, correct:True
# pred:0.5716655850410461,label:1.0, correct:True
# pred:0.5714882612228394,label:1.0, correct:True
# pred:0.4572136104106903,label:1.0, correct:False
# pred:0.19249479472637177,label:0.0, correct:True
# pred:0.55363529920578,label:1.0, correct:True
# pred:0.5719339847564697,label:1.0, correct:True
# pred:0.1809254288673401,label:0.0, correct:True
# pred:0.5712229013442993,label:1.0, correct:True
# pred:0.2962488830089569,label:0.0, correct:True
# pred:0.38495561480522156,label:0.0, correct:True
# pred:0.571639358997345,label:1.0, correct:True
# pred:0.4734033942222595,label:1.0, correct:False
# pred:0.5027886629104614,label:1.0, correct:True
# pred:0.5461766123771667,label:1.0, correct:True
# pred:0.5712059140205383,label:1.0, correct:True
# pred:0.23004117608070374,label:0.0, correct:True
# pred:0.17817693948745728,label:0.0, correct:True
# pred:0.5689566731452942,label:1.0, correct:True
# pred:0.5127657651901245,label:1.0, correct:True
# pred:0.5720296502113342,label:1.0, correct:True
# pred:0.5717678666114807,label:1.0, correct:True
# pred:0.5714876055717468,label:1.0, correct:True
# pred:0.56417316198349,label:1.0, correct:True
# pred:0.5006971955299377,label:0.0, correct:False
# pred:0.5716872811317444,label:1.0, correct:True
# pred:0.505598247051239,label:1.0, correct:True
# pred:0.571907639503479,label:1.0, correct:True
# pred:0.1747288703918457,label:0.0, correct:True
# pred:0.5711509585380554,label:1.0, correct:True
# pred:0.27619609236717224,label:0.0, correct:True
# pred:0.5716564655303955,label:1.0, correct:True
# pred:0.40523383021354675,label:1.0, correct:False
# pred:0.5000488758087158,label:0.0, correct:False
# pred:0.5612727999687195,label:1.0, correct:True
# pred:0.571512758731842,label:1.0, correct:True
# pred:0.3058820962905884,label:0.0, correct:True
# pred:0.4996614456176758,label:0.0, correct:True
# pred:0.5720034241676331,label:1.0, correct:True
# pred:0.4911491870880127,label:1.0, correct:False
# pred:0.19612620770931244,label:0.0, correct:True
# pred:0.43471190333366394,label:0.0, correct:True
# pred:0.5721142292022705,label:1.0, correct:True
# pred:0.5721126198768616,label:1.0, correct:True
# pred:0.20537331700325012,label:0.0, correct:True
# pred:0.4958456754684448,label:1.0, correct:False
# pred:0.3277680277824402,label:0.0, correct:True
# pred:0.5719210505485535,label:1.0, correct:True
# pred:0.5669578313827515,label:1.0, correct:True
# pred:0.5714142322540283,label:1.0, correct:True
# pred:0.5717659592628479,label:1.0, correct:True
# pred:0.1729763299226761,label:0.0, correct:True
# pred:0.17934265732765198,label:0.0, correct:True
# pred:0.571263313293457,label:1.0, correct:True
# pred:0.5721419453620911,label:1.0, correct:True
# pred:0.5159052610397339,label:1.0, correct:True
# pred:0.571377694606781,label:1.0, correct:True
# pred:0.5711344480514526,label:1.0, correct:True
# pred:0.5719610452651978,label:1.0, correct:True
# pred:0.5717170834541321,label:1.0, correct:True
# pred:0.4994950592517853,label:0.0, correct:True
# pred:0.5711988210678101,label:1.0, correct:True
# pred:0.5650402903556824,label:1.0, correct:True
# pred:0.3612476885318756,label:0.0, correct:True
# pred:0.563203752040863,label:1.0, correct:True
# pred:0.5712702870368958,label:1.0, correct:True
# pred:0.5713121294975281,label:1.0, correct:True
# pred:0.5692908763885498,label:1.0, correct:True
# pred:0.5719925165176392,label:1.0, correct:True
# pred:0.5717139840126038,label:1.0, correct:True
# pred:0.5720292329788208,label:1.0, correct:True
# pred:0.5716403126716614,label:1.0, correct:True
# pred:0.18027344346046448,label:0.0, correct:True
# pred:0.49494668841362,label:0.0, correct:True
# pred:0.5712783336639404,label:1.0, correct:True
# pred:0.22475725412368774,label:0.0, correct:True
# pred:0.5711640119552612,label:1.0, correct:True
# pred:0.5713948011398315,label:1.0, correct:True
# pred:0.384784072637558,label:1.0, correct:False
# pred:0.29601335525512695,label:0.0, correct:True
# pred:0.5077323913574219,label:0.0, correct:False
# pred:0.5716469287872314,label:1.0, correct:True
# pred:0.18832466006278992,label:0.0, correct:True
# pred:0.1717335730791092,label:0.0, correct:True
# pred:0.5720944404602051,label:1.0, correct:True
# pred:0.572091281414032,label:1.0, correct:True
# pred:0.3199584186077118,label:0.0, correct:True
# pred:0.5606387853622437,label:1.0, correct:True
# pred:0.19251424074172974,label:0.0, correct:True
# pred:0.5713093876838684,label:1.0, correct:True
# pred:0.2621552348136902,label:0.0, correct:True
# pred:0.5011981129646301,label:1.0, correct:True
# pred:0.5712544918060303,label:1.0, correct:True
# pred:0.5711830854415894,label:1.0, correct:True
# pred:0.5711469054222107,label:1.0, correct:True
# pred:0.5240841507911682,label:0.0, correct:False
# pred:0.5720701813697815,label:1.0, correct:True
# pred:0.5719436407089233,label:1.0, correct:True
# pred:0.5685607194900513,label:1.0, correct:True
# pred:0.536855161190033,label:1.0, correct:True
# pred:0.1861511915922165,label:0.0, correct:True
# pred:0.18518832325935364,label:0.0, correct:True
# pred:0.5720499753952026,label:1.0, correct:True
# pred:0.5718206763267517,label:1.0, correct:True
# pred:0.527837336063385,label:1.0, correct:True
# pred:0.48561185598373413,label:1.0, correct:False
# pred:0.1739589422941208,label:0.0, correct:True
# pred:0.5707066655158997,label:1.0, correct:True
# pred:0.4474797248840332,label:0.0, correct:True
# pred:0.5713740587234497,label:1.0, correct:True
# pred:0.5718129277229309,label:1.0, correct:True
# pred:0.571550190448761,label:1.0, correct:True
# pred:0.5069302320480347,label:1.0, correct:True
# pred:0.5709913969039917,label:1.0, correct:True
# pred:0.4958360493183136,label:0.0, correct:True
# pred:0.5713729858398438,label:1.0, correct:True
# pred:0.5719060301780701,label:0.0, correct:False
# pred:0.5719884634017944,label:1.0, correct:True
# pred:0.5719689726829529,label:1.0, correct:True
# pred:0.48292505741119385,label:1.0, correct:False
# pred:0.5718603730201721,label:1.0, correct:True
# pred:0.18137167394161224,label:0.0, correct:True
# pred:0.24400083720684052,label:0.0, correct:True
# pred:0.5717889666557312,label:1.0, correct:True
# pred:0.5706822276115417,label:0.0, correct:False
# pred:0.18464046716690063,label:0.0, correct:True
# pred:0.5164972543716431,label:1.0, correct:True
# pred:0.1746770441532135,label:0.0, correct:True
# pred:0.5715032815933228,label:1.0, correct:True
# pred:0.5719836950302124,label:1.0, correct:True
# pred:0.5005706548690796,label:0.0, correct:False
# pred:0.18046709895133972,label:0.0, correct:True
# pred:0.5719823837280273,label:1.0, correct:True
# pred:0.17083555459976196,label:0.0, correct:True
# pred:0.28487151861190796,label:0.0, correct:True
# pred:0.18298965692520142,label:0.0, correct:True
# pred:0.5509936213493347,label:0.0, correct:False
# pred:0.5701174736022949,label:1.0, correct:True
# pred:0.5720157623291016,label:0.0, correct:False
# pred:0.4394560754299164,label:1.0, correct:False
# pred:0.5693491101264954,label:1.0, correct:True
# pred:0.3626263439655304,label:0.0, correct:True
# pred:0.17871609330177307,label:0.0, correct:True
# pred:0.5721352696418762,label:1.0, correct:True
# pred:0.5713363885879517,label:1.0, correct:True
# pred:0.5711632966995239,label:1.0, correct:True
# pred:0.21272362768650055,label:0.0, correct:True
# pred:0.18122857809066772,label:0.0, correct:True
# pred:0.5711082816123962,label:1.0, correct:True
# pred:0.4937804043292999,label:1.0, correct:False
# pred:0.5336257815361023,label:1.0, correct:True
# pred:0.5712674856185913,label:1.0, correct:True
# pred:0.5397151708602905,label:1.0, correct:True
# pred:0.572059154510498,label:1.0, correct:True
# pred:0.17814373970031738,label:0.0, correct:True
# pred:0.5711321830749512,label:1.0, correct:True
# pred:0.5071996450424194,label:1.0, correct:True
# pred:0.5719871520996094,label:1.0, correct:True
# pred:0.5651822090148926,label:1.0, correct:True
# pred:0.5713821649551392,label:1.0, correct:True
# pred:0.1900755763053894,label:0.0, correct:True
# pred:0.5480788350105286,label:0.0, correct:False
# pred:0.23660187423229218,label:0.0, correct:True
# pred:0.5713900923728943,label:1.0, correct:True
# pred:0.338291734457016,label:1.0, correct:False
# pred:0.5716279745101929,label:1.0, correct:True
# pred:0.18107746541500092,label:0.0, correct:True
# pred:0.5711892247200012,label:1.0, correct:True
# pred:0.4978187382221222,label:0.0, correct:True
# pred:0.5470935106277466,label:1.0, correct:True
# pred:0.2698315978050232,label:0.0, correct:True
# pred:0.1871664971113205,label:0.0, correct:True
# pred:0.48076581954956055,label:1.0, correct:False
# pred:0.18442402780056,label:0.0, correct:True
# pred:0.1960771083831787,label:0.0, correct:True
# pred:0.5719912052154541,label:1.0, correct:True
# pred:0.24742528796195984,label:0.0, correct:True
# pred:0.5713552236557007,label:1.0, correct:True
# pred:0.21029794216156006,label:0.0, correct:True
# pred:0.5714612007141113,label:1.0, correct:True
# pred:0.5235140323638916,label:0.0, correct:False
# pred:0.5208717584609985,label:0.0, correct:False
# pred:0.5712463855743408,label:1.0, correct:True
# pred:0.5591012239456177,label:1.0, correct:True
# pred:0.5713913440704346,label:1.0, correct:True
# pred:0.4969308376312256,label:1.0, correct:False
# pred:0.33763185143470764,label:0.0, correct:True
# pred:0.2609449028968811,label:0.0, correct:True
# pred:0.18896514177322388,label:0.0, correct:True
# pred:0.4964270293712616,label:0.0, correct:True
# pred:0.5711479187011719,label:1.0, correct:True
# pred:0.571348249912262,label:1.0, correct:True
# pred:0.5102271437644958,label:1.0, correct:True
# pred:0.5712540745735168,label:1.0, correct:True
# pred:0.5718430280685425,label:1.0, correct:True
# pred:0.19204476475715637,label:0.0, correct:True
# pred:0.1764858216047287,label:0.0, correct:True
# pred:0.18358859419822693,label:0.0, correct:True
# pred:0.5721390843391418,label:1.0, correct:True
# pred:0.5714009404182434,label:1.0, correct:True
# pred:0.5716923475265503,label:1.0, correct:True
# pred:0.4587850868701935,label:0.0, correct:True
# pred:0.5717959403991699,label:1.0, correct:True
# pred:0.4976457953453064,label:0.0, correct:True
# pred:0.5720081329345703,label:1.0, correct:True
# pred:0.47985202074050903,label:1.0, correct:False
# pred:0.4963715672492981,label:0.0, correct:True
# pred:0.5708441734313965,label:1.0, correct:True
# pred:0.19398830831050873,label:0.0, correct:True
# pred:0.1987975388765335,label:0.0, correct:True
# pred:0.5714324712753296,label:1.0, correct:True
# pred:0.571584939956665,label:1.0, correct:True
# pred:0.5720679759979248,label:1.0, correct:True
# pred:0.5719055533409119,label:1.0, correct:True
# pred:0.5713152289390564,label:1.0, correct:True
# pred:0.22344940900802612,label:0.0, correct:True
# pred:0.5719618201255798,label:1.0, correct:True
# pred:0.5697600245475769,label:1.0, correct:True
# pred:0.5720196962356567,label:1.0, correct:True
# pred:0.30859091877937317,label:1.0, correct:False
# pred:0.3358813524246216,label:0.0, correct:True
# pred:0.5711714029312134,label:1.0, correct:True
# pred:0.17265684902668,label:0.0, correct:True
# pred:0.18289396166801453,label:0.0, correct:True
# pred:0.5713764429092407,label:1.0, correct:True
# pred:0.290072500705719,label:0.0, correct:True
# pred:0.5718008279800415,label:1.0, correct:True
# pred:0.5111591219902039,label:1.0, correct:True
# pred:0.19058914482593536,label:0.0, correct:True
# pred:0.5002915859222412,label:1.0, correct:True
# pred:0.567362904548645,label:1.0, correct:True
# pred:0.4999108612537384,label:0.0, correct:True
# pred:0.20057472586631775,label:0.0, correct:True
# pred:0.25126147270202637,label:0.0, correct:True
# pred:0.5718369483947754,label:1.0, correct:True
# pred:0.571630597114563,label:0.0, correct:False
# pred:0.5717341303825378,label:1.0, correct:True
# pred:0.17235203087329865,label:0.0, correct:True
# pred:0.5715624094009399,label:1.0, correct:True
# pred:0.5715468525886536,label:1.0, correct:True
# pred:0.49723687767982483,label:0.0, correct:True
# pred:0.49881288409233093,label:1.0, correct:False
# pred:0.2191695123910904,label:0.0, correct:True
# pred:0.4998355507850647,label:1.0, correct:False
# pred:0.17086781561374664,label:0.0, correct:True
# pred:0.3540639579296112,label:0.0, correct:True
# pred:0.5715567469596863,label:1.0, correct:True
# pred:0.5719908475875854,label:1.0, correct:True
# pred:0.1801040768623352,label:0.0, correct:True
# pred:0.4985230267047882,label:0.0, correct:True
# pred:0.5713031888008118,label:1.0, correct:True
# pred:0.17648550868034363,label:0.0, correct:True
# pred:0.2897738516330719,label:0.0, correct:True
# pred:0.54883873462677,label:0.0, correct:False
# pred:0.18512852489948273,label:0.0, correct:True
# pred:0.4984130263328552,label:0.0, correct:True
# pred:0.17524446547031403,label:0.0, correct:True
# pred:0.571793794631958,label:1.0, correct:True
# pred:0.3468432128429413,label:0.0, correct:True
# pred:0.5717976093292236,label:1.0, correct:True
# pred:0.45002055168151855,label:0.0, correct:True
# pred:0.4989576041698456,label:0.0, correct:True
# pred:0.5705395936965942,label:1.0, correct:True
# pred:0.5716876983642578,label:1.0, correct:True
# pred:0.27852746844291687,label:0.0, correct:True
# pred:0.49987271428108215,label:0.0, correct:True
# pred:0.5719975233078003,label:1.0, correct:True
# pred:0.4966936409473419,label:0.0, correct:True
# pred:0.5720502138137817,label:1.0, correct:True
# pred:0.2083422690629959,label:0.0, correct:True
# pred:0.5720350742340088,label:1.0, correct:True
# pred:0.5680130124092102,label:1.0, correct:True
# pred:0.5413520336151123,label:1.0, correct:True
# pred:0.3174915015697479,label:0.0, correct:True
# pred:0.534125030040741,label:0.0, correct:False
# pred:0.49503278732299805,label:0.0, correct:True
# pred:0.5714016556739807,label:1.0, correct:True
# pred:0.5044578909873962,label:1.0, correct:True
# pred:0.37576889991760254,label:0.0, correct:True
# pred:0.2506105899810791,label:0.0, correct:True
# pred:0.572064220905304,label:1.0, correct:True
# pred:0.518607497215271,label:1.0, correct:True
# pred:0.5712929964065552,label:1.0, correct:True
# pred:0.5711691379547119,label:1.0, correct:True
# pred:0.18269772827625275,label:0.0, correct:True
# pred:0.534755289554596,label:1.0, correct:True
# pred:0.5662964582443237,label:1.0, correct:True
# pred:0.2155066877603531,label:0.0, correct:True
# pred:0.5720771551132202,label:1.0, correct:True
# pred:0.5713905692100525,label:1.0, correct:True
# pred:0.19752585887908936,label:0.0, correct:True
# pred:0.56966632604599,label:1.0, correct:True
# pred:0.5109485983848572,label:1.0, correct:True
# pred:0.5718633532524109,label:0.0, correct:False
# pred:0.5719869136810303,label:1.0, correct:True
# pred:0.5686131715774536,label:1.0, correct:True
# pred:0.5369979739189148,label:1.0, correct:True
# pred:0.5711217522621155,label:1.0, correct:True
# pred:0.5718973278999329,label:1.0, correct:True
# pred:0.5043531060218811,label:1.0, correct:True
# pred:0.40169039368629456,label:0.0, correct:True
# pred:0.5713989734649658,label:1.0, correct:True
# pred:0.20144042372703552,label:0.0, correct:True
# pred:0.17446421086788177,label:0.0, correct:True
# pred:0.5719931721687317,label:1.0, correct:True
# pred:0.5004600882530212,label:0.0, correct:False
# pred:0.5705763101577759,label:0.0, correct:False
# pred:0.5012475252151489,label:0.0, correct:False
# pred:0.18836310505867004,label:0.0, correct:True
# pred:0.3351392149925232,label:0.0, correct:True
# pred:0.5715994238853455,label:1.0, correct:True
# pred:0.5354508757591248,label:1.0, correct:True
# pred:0.17155428230762482,label:0.0, correct:True
# pred:0.5712357759475708,label:1.0, correct:True
# pred:0.5038611888885498,label:1.0, correct:True
# pred:0.5716373324394226,label:1.0, correct:True
# pred:0.17477403581142426,label:0.0, correct:True
# pred:0.350581556558609,label:0.0, correct:True
# pred:0.39829394221305847,label:0.0, correct:True
# pred:0.5717246532440186,label:1.0, correct:True
# pred:0.2541024684906006,label:0.0, correct:True
# pred:0.5715336203575134,label:1.0, correct:True
# pred:0.1805332750082016,label:0.0, correct:True
# pred:0.5088986754417419,label:1.0, correct:True
# pred:0.5711948275566101,label:1.0, correct:True
# pred:0.21523942053318024,label:0.0, correct:True
# pred:0.571496844291687,label:0.0, correct:False
# pred:0.5714111924171448,label:1.0, correct:True
# pred:0.17277492582798004,label:0.0, correct:True
# pred:0.18737733364105225,label:0.0, correct:True
# pred:0.5719736218452454,label:1.0, correct:True
# pred:0.17773258686065674,label:0.0, correct:True
# pred:0.5718674659729004,label:1.0, correct:True
# pred:0.5013447403907776,label:0.0, correct:False
# pred:0.571347713470459,label:1.0, correct:True
# pred:0.5719994306564331,label:1.0, correct:True
# pred:0.5714554190635681,label:1.0, correct:True
# pred:0.5718917846679688,label:1.0, correct:True
# pred:0.5093360543251038,label:0.0, correct:False
# pred:0.5719993114471436,label:1.0, correct:True
# pred:0.21606600284576416,label:0.0, correct:True
# pred:0.5678813457489014,label:1.0, correct:True
# pred:0.5721015334129333,label:1.0, correct:True
# pred:0.5712319612503052,label:1.0, correct:True
# pred:0.5659730434417725,label:1.0, correct:True
# pred:0.5031442642211914,label:0.0, correct:False
# pred:0.5269959568977356,label:1.0, correct:True
# pred:0.1916867345571518,label:0.0, correct:True
# pred:0.5719270706176758,label:1.0, correct:True
# pred:0.5713375210762024,label:1.0, correct:True
# pred:0.5037277340888977,label:0.0, correct:False
# pred:0.18567366898059845,label:0.0, correct:True
# pred:0.5716204047203064,label:1.0, correct:True
# pred:0.20283019542694092,label:0.0, correct:True
# pred:0.5720069408416748,label:1.0, correct:True
# pred:0.571906566619873,label:1.0, correct:True
# pred:0.34689822793006897,label:0.0, correct:True
# pred:0.2624177932739258,label:0.0, correct:True
# pred:0.18324407935142517,label:0.0, correct:True
# pred:0.31297191977500916,label:0.0, correct:True
# pred:0.5643519759178162,label:1.0, correct:True
# pred:0.5011262893676758,label:0.0, correct:False
# pred:0.2096090465784073,label:0.0, correct:True
# pred:0.17673683166503906,label:0.0, correct:True
# pred:0.20015190541744232,label:0.0, correct:True
# pred:0.5718805193901062,label:1.0, correct:True
# pred:0.5720348954200745,label:1.0, correct:True
# pred:0.5720129013061523,label:1.0, correct:True
# pred:0.17738114297389984,label:0.0, correct:True
# pred:0.5713903307914734,label:1.0, correct:True
# pred:0.18724539875984192,label:0.0, correct:True
# pred:0.5720257759094238,label:1.0, correct:True
# pred:0.571840763092041,label:1.0, correct:True
# pred:0.569719135761261,label:1.0, correct:True
# pred:0.23967933654785156,label:0.0, correct:True
# pred:0.24343633651733398,label:0.0, correct:True
# pred:0.32123687863349915,label:0.0, correct:True
# pred:0.5422843098640442,label:1.0, correct:True
# pred:0.5717923045158386,label:1.0, correct:True
# pred:0.20177476108074188,label:0.0, correct:True
# pred:0.5712420344352722,label:1.0, correct:True
# pred:0.559032142162323,label:1.0, correct:True
# pred:0.17997349798679352,label:0.0, correct:True
# pred:0.5672900676727295,label:1.0, correct:True
# pred:0.5718821287155151,label:1.0, correct:True
# pred:0.3376098871231079,label:0.0, correct:True
# pred:0.5078287124633789,label:1.0, correct:True
# pred:0.5714130401611328,label:1.0, correct:True
# pred:0.5714074969291687,label:1.0, correct:True
# pred:0.18215225636959076,label:0.0, correct:True
# pred:0.5711730122566223,label:1.0, correct:True
# pred:0.5714663863182068,label:1.0, correct:True
# pred:0.19724714756011963,label:0.0, correct:True
# pred:0.16558951139450073,label:0.0, correct:True
# pred:0.5480219125747681,label:1.0, correct:True
# pred:0.36139926314353943,label:0.0, correct:True
# pred:0.5711910724639893,label:1.0, correct:True
# pred:0.5007150769233704,label:0.0, correct:False
# pred:0.5719448924064636,label:1.0, correct:True
# pred:0.36559513211250305,label:0.0, correct:True
# pred:0.5714719891548157,label:1.0, correct:True
# pred:0.21573369204998016,label:0.0, correct:True
# pred:0.5720721483230591,label:1.0, correct:True
# pred:0.5712413787841797,label:1.0, correct:True
# pred:0.5720207095146179,label:1.0, correct:True
# pred:0.5713483095169067,label:1.0, correct:True
# pred:0.571953535079956,label:1.0, correct:True
# pred:0.5719457864761353,label:1.0, correct:True
# pred:0.44449153542518616,label:0.0, correct:True
# pred:0.5713980793952942,label:1.0, correct:True
# pred:0.36115506291389465,label:0.0, correct:True
# pred:0.5712155699729919,label:1.0, correct:True
# pred:0.1919412612915039,label:0.0, correct:True
# pred:0.5612645745277405,label:1.0, correct:True
# pred:0.17259153723716736,label:0.0, correct:True
# pred:0.5718920230865479,label:1.0, correct:True
# pred:0.5716496706008911,label:1.0, correct:True
# pred:0.1762227863073349,label:0.0, correct:True
# pred:0.571729302406311,label:1.0, correct:True
# pred:0.21430912613868713,label:0.0, correct:True
# pred:0.1968734711408615,label:0.0, correct:True
# pred:0.5720601677894592,label:1.0, correct:True
# pred:0.45388469099998474,label:0.0, correct:True
# pred:0.5719766020774841,label:1.0, correct:True
# pred:0.5720160007476807,label:1.0, correct:True
# pred:0.5711869597434998,label:1.0, correct:True
# pred:0.5010184049606323,label:0.0, correct:False
# pred:0.31866753101348877,label:1.0, correct:False
# pred:0.4979061782360077,label:0.0, correct:True
# pred:0.5716278553009033,label:1.0, correct:True
# pred:0.3643084764480591,label:0.0, correct:True
# pred:0.572012722492218,label:1.0, correct:True
# pred:0.509256899356842,label:1.0, correct:True
# pred:0.2904490828514099,label:0.0, correct:True
# pred:0.17840775847434998,label:0.0, correct:True
# pred:0.1854577213525772,label:0.0, correct:True
# pred:0.5710721611976624,label:1.0, correct:True
# pred:0.5012663006782532,label:0.0, correct:False
# pred:0.5720291137695312,label:1.0, correct:True
# pred:0.532134473323822,label:0.0, correct:False
# pred:0.5712968111038208,label:1.0, correct:True
# pred:0.18324385583400726,label:0.0, correct:True
# pred:0.57133948802948,label:1.0, correct:True
# pred:0.571514904499054,label:1.0, correct:True
# pred:0.3607381582260132,label:1.0, correct:False
# pred:0.5010567307472229,label:0.0, correct:False
# pred:0.5017231106758118,label:0.0, correct:False
# pred:0.5720251202583313,label:1.0, correct:True
# pred:0.558448076248169,label:1.0, correct:True
# pred:0.5711286664009094,label:1.0, correct:True
# pred:0.5712699890136719,label:1.0, correct:True
# pred:0.5618427395820618,label:1.0, correct:True
# pred:0.5713856816291809,label:1.0, correct:True
# pred:0.5704522728919983,label:1.0, correct:True
# pred:0.5710089802742004,label:0.0, correct:False
# pred:0.4037690758705139,label:1.0, correct:False
# pred:0.5720778107643127,label:1.0, correct:True
# pred:0.3823029696941376,label:0.0, correct:True
# pred:0.5717130899429321,label:1.0, correct:True
# pred:0.17766603827476501,label:0.0, correct:True
# pred:0.301607608795166,label:0.0, correct:True
# pred:0.5711213946342468,label:1.0, correct:True
# pred:0.5001235008239746,label:0.0, correct:False
# pred:0.5719037652015686,label:1.0, correct:True
# pred:0.5710116624832153,label:1.0, correct:True
# pred:0.5555947422981262,label:1.0, correct:True
# pred:0.5713054537773132,label:1.0, correct:True
# pred:0.5718909502029419,label:1.0, correct:True
# pred:0.2879358232021332,label:0.0, correct:True
# pred:0.4994114935398102,label:0.0, correct:True
# pred:0.45845770835876465,label:0.0, correct:True
# pred:0.49995672702789307,label:0.0, correct:True
# pred:0.5665337443351746,label:0.0, correct:False
# pred:0.47128206491470337,label:0.0, correct:True
# pred:0.5720826387405396,label:1.0, correct:True
# pred:0.2922774851322174,label:0.0, correct:True
# pred:0.18519844114780426,label:0.0, correct:True
# pred:0.571530282497406,label:1.0, correct:True
# pred:0.5717929601669312,label:1.0, correct:True
# pred:0.35905662178993225,label:0.0, correct:True
# pred:0.4709949791431427,label:0.0, correct:True
# pred:0.210707426071167,label:0.0, correct:True
# pred:0.5676440596580505,label:1.0, correct:True
# pred:0.5714558959007263,label:1.0, correct:True
# pred:0.4983879029750824,label:0.0, correct:True
# pred:0.18188565969467163,label:0.0, correct:True
# pred:0.5710182785987854,label:1.0, correct:True
# pred:0.5067986845970154,label:1.0, correct:True
# pred:0.529931902885437,label:1.0, correct:True
# pred:0.5708141922950745,label:1.0, correct:True
# pred:0.5197624564170837,label:1.0, correct:True
# pred:0.383078008890152,label:0.0, correct:True
# pred:0.23374351859092712,label:0.0, correct:True
# pred:0.5718269944190979,label:1.0, correct:True
# pred:0.18268483877182007,label:0.0, correct:True
# pred:0.1815410703420639,label:0.0, correct:True
# pred:0.5720918774604797,label:1.0, correct:True
# pred:0.5712568759918213,label:1.0, correct:True
# pred:0.20337533950805664,label:0.0, correct:True
# pred:0.5716617703437805,label:1.0, correct:True
# pred:0.32983431220054626,label:0.0, correct:True
# pred:0.5718115568161011,label:1.0, correct:True
# pred:0.5713047385215759,label:1.0, correct:True
# pred:0.22435609996318817,label:0.0, correct:True
# pred:0.18248766660690308,label:0.0, correct:True
# pred:0.5710306167602539,label:1.0, correct:True
# pred:0.5716789960861206,label:1.0, correct:True
# pred:0.1753624826669693,label:0.0, correct:True
# pred:0.5711591839790344,label:1.0, correct:True
# pred:0.5039702653884888,label:0.0, correct:False
# pred:0.18915413320064545,label:0.0, correct:True
# accuracy: 0.877444589308996
